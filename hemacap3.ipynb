# %%
#importing 2022 laptop dataset in csv format
import pandas as pd
lap=pd.read_csv("C:\\Users\\HP\\Downloads\\Cleaned_Laptop_data.csv")
lap
# Out:
#       brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# 0      ASUS   Celeron           Intel   Celeron Dual         Missing      4
# 1      ASUS  VivoBook           Intel        Core i3            10th      8
# 2      ASUS  Vivobook           Intel        Core i3            10th      8
# 3        HP      Core           Intel        Core i3            11th      8
# 4        HP      Core           Intel        Core i5            11th      8
# ..      ...       ...             ...            ...             ...    ...
# 891    DELL      Core           Intel        Core i3            10th      8
# 892    DELL      Core           Intel        Core i3            10th      8
# 893      HP  Pavilion           Intel        Core i5             8th      8
# 894    ASUS  Vivobook           Intel        Core i3            10th      4
# 895  Lenovo       v15           Intel        Core i3            10th      4
#
# ...

# %%
#to get laptop first parts
lap.head()
# Out:
#   brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# 0  ASUS   Celeron           Intel   Celeron Dual         Missing      4
# 1  ASUS  VivoBook           Intel        Core i3            10th      8
# 2  ASUS  Vivobook           Intel        Core i3            10th      8
# 3    HP      Core           Intel        Core i3            11th      8
# 4    HP      Core           Intel        Core i5            11th      8
#
#   ram_type  ssd   hdd       os  ...  display_size  warranty Touchscreen  \
# 0     DDR4    0  1024  Windows  ...          15.6         1          No
# 1     DDR4  512     0  Windows  ...          15.6         1          No
# 2     DDR4    0  1024  Windows  ...          14.1         1          No
# 3     DDR4  512     0  Windows  ...          15.6         1          No
# 4     DDR4  512     0  Windows  ...          15.6         0          No
#
#   msoffice  latest_price old_price discount  star_rating  ratings  reviews
# ...

# %%
#to get laptop last parts
lap.tail()
# Out:
#       brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# 891    DELL      Core           Intel        Core i3            10th      8
# 892    DELL      Core           Intel        Core i3            10th      8
# 893      HP  Pavilion           Intel        Core i5             8th      8
# 894    ASUS  Vivobook           Intel        Core i3            10th      4
# 895  Lenovo       v15           Intel        Core i3            10th      4
#
#     ram_type  ssd   hdd       os  ...  display_size  warranty Touchscreen  \
# 891     DDR4  256  1024  Windows  ...          15.6         0          No
# 892     DDR4    0  1024  Windows  ...         14.96         0          No
# 893     DDR4  128     0  Windows  ...          13.3         1          No
# 894     DDR4    0  1024  Windows  ...          14.1         0          No
# 895     DDR4    0  1024  Missing  ...          15.6         0          No
#
# ...

# %%
#to calucate discount mean of laptop
lap.discount.mean()
# Out:
# 18.527901785714285

# %%
#to calucate latest_price mean of laptop
lap.latest_price.mean()
# Out:
# 76309.86049107143

# %%
#to describe some mathematical terms of laptop dataset
lap.describe()
# Out:
#                ssd          hdd      os_bit  graphic_card_gb    warranty  \
# count   896.000000   896.000000  896.000000       896.000000  896.000000
# mean    431.750000   190.857143   59.178571         1.198661    0.691964
# std     316.436824   401.181158   11.453644         2.057454    0.606282
# min       0.000000     0.000000   32.000000         0.000000    0.000000
# 25%     256.000000     0.000000   64.000000         0.000000    0.000000
# 50%     512.000000     0.000000   64.000000         0.000000    1.000000
# 75%     512.000000     0.000000   64.000000         2.000000    1.000000
# max    3072.000000  2048.000000   64.000000         8.000000    3.000000
#
#         latest_price      old_price    discount  star_rating       ratings  \
# count     896.000000     896.000000  896.000000   896.000000    896.000000
# mean    76309.860491   88134.154018   18.527902     2.980469    367.391741
# std     46613.354368   55719.645554   10.508486     1.965254   1106.309355
# ...

# %%
#to get some laptop information dtypes
lap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            896 non-null    object
#  1   model            896 non-null    object
#  2   processor_brand  896 non-null    object
#  3   processor_name   895 non-null    object
#  4   processor_gnrtn  896 non-null    object
#  5   ram_gb           871 non-null    object
#  6   ram_type         871 non-null    object
#  7   ssd              896 non-null    int64
#  8   hdd              896 non-null    int64
#  9   os               896 non-null    object
#  10  os_bit           896 non-null    int64
#  11  graphic_card_gb  896 non-null    int64
#  12  weight           896 non-null    object
#  13  display_size     896 non-null    object
#  14  warranty         896 non-null    int64
#  15  Touchscreen      896 non-null    object
#  16  msoffice         896 non-null    object
# ...

# %%
#while buying laptop, the priority of customer choosen 
lap[['brand','model','ram_gb','ram_type','ssd','os','warranty','msoffice']]
# Out:
#       brand     model ram_gb ram_type  ssd       os  warranty msoffice
# 0      ASUS   Celeron      4     DDR4    0  Windows         1       No
# 1      ASUS  VivoBook      8     DDR4  512  Windows         1       No
# 2      ASUS  Vivobook      8     DDR4    0  Windows         1       No
# 3        HP      Core      8     DDR4  512  Windows         1      Yes
# 4        HP      Core      8     DDR4  512  Windows         0       No
# ..      ...       ...    ...      ...  ...      ...       ...      ...
# 891    DELL      Core      8     DDR4  256  Windows         0       No
# 892    DELL      Core      8     DDR4    0  Windows         0       No
# 893      HP  Pavilion      8     DDR4  128  Windows         1       No
# 894    ASUS  Vivobook      4     DDR4    0  Windows         0       No
# 895  Lenovo       v15      4     DDR4    0  Missing         0       No
#
# [896 rows x 8 columns]

# %%
#to get laptop specification
lap[['brand','processor_brand','weight','display_size']]
# Out:
#       brand processor_brand      weight display_size
# 0      ASUS           Intel      Casual         15.6
# 1      ASUS           Intel      Casual         15.6
# 2      ASUS           Intel      Casual         14.1
# 3        HP           Intel  ThinNlight         15.6
# 4        HP           Intel  ThinNlight         15.6
# ..      ...             ...         ...          ...
# 891    DELL           Intel  ThinNlight         15.6
# 892    DELL           Intel  ThinNlight        14.96
# 893      HP           Intel  ThinNlight         13.3
# 894    ASUS           Intel  ThinNlight         14.1
# 895  Lenovo           Intel      Casual         15.6
#
# [896 rows x 4 columns]

# %%
#to display min rows on datset of laptop
pd.options.display.min_rows=25
lap
# Out:
#       brand       model processor_brand processor_name processor_gnrtn ram_gb  \
# 0      ASUS     Celeron           Intel   Celeron Dual         Missing      4
# 1      ASUS    VivoBook           Intel        Core i3            10th      8
# 2      ASUS    Vivobook           Intel        Core i3            10th      8
# 3        HP        Core           Intel        Core i3            11th      8
# 4        HP        Core           Intel        Core i5            11th      8
# 5    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 6        HP         15s             AMD        Ryzen 3         Missing      8
# 7      ASUS        Core           Intel        Core i3            11th      4
# 8      DELL      Vostro           Intel        Core i3            10th      8
# 9    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 10       HP        Core           Intel        Core i5            11th      8
# ...

# %%
#to display max rows on datset of laptop
pd.options.display.max_rows=60
lap
# Out:
#       brand       model processor_brand processor_name processor_gnrtn ram_gb  \
# 0      ASUS     Celeron           Intel   Celeron Dual         Missing      4
# 1      ASUS    VivoBook           Intel        Core i3            10th      8
# 2      ASUS    Vivobook           Intel        Core i3            10th      8
# 3        HP        Core           Intel        Core i3            11th      8
# 4        HP        Core           Intel        Core i5            11th      8
# 5    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 6        HP         15s             AMD        Ryzen 3         Missing      8
# 7      ASUS        Core           Intel        Core i3            11th      4
# 8      DELL      Vostro           Intel        Core i3            10th      8
# 9    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 10       HP        Core           Intel        Core i5            11th      8
# ...

# %%
#to get laptop for brand specification
lap.brand
# Out:
# 0        ASUS
# 1        ASUS
# 2        ASUS
# 3          HP
# 4          HP
# 5      Lenovo
# 6          HP
# 7        ASUS
# 8        DELL
# 9      Lenovo
# 10         HP
# 11         HP
#         ...
# 884    Lenovo
# 885        HP
# 886      acer
# 887        HP
# 888      DELL
# 889      acer
# 890     APPLE
# 891      DELL
# 892      DELL
# 893        HP
# 894      ASUS
# 895    Lenovo
# Name: brand, Length: 896, dtype: object

# %%
#to get the laptop dataset which has ramgbof 16 only
lap_gb=lap[lap['ram_gb']=="16"]
lap_gb
# Out:
#       brand       model processor_brand processor_name processor_gnrtn ram_gb  \
# 17       HP    Pavilion           Intel        Core i5            11th     16
# 22     ASUS    VivoBook           Intel        Core i7            10th     16
# 31   Lenovo     Ideapad           Intel        Core i5            11th     16
# 37      MSI        GF65           Intel        Core i7            10th     16
# 49   Lenovo     IdeaPad           Intel        Core i5            11th     16
# 64       HP    Pavilion             AMD        Ryzen 7         Missing     16
# 74    APPLE     MacBook           Apple   M1 Processor         Missing     16
# 75     acer    Predator           Intel        Core i7            11th     16
# 76     ASUS        ASUS             AMD        Ryzen 7         Missing     16
# 86      MSI      Katana           Intel        Core i5            11th     16
# 87    APPLE     MacBook           Apple   M1 Processor         Missing     16
# ...

# %%
##to get the laptop dataset which has ramgbof 16 only and brand of it
lap1=lap[(lap['brand']=="HP")&(lap['ram_gb']=="16")]
lap1
# Out:
#     brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# 17     HP  Pavilion           Intel        Core i5            11th     16
# 64     HP  Pavilion             AMD        Ryzen 7         Missing     16
# 143    HP  Pavilion           Intel        Core i5            11th     16
# 172    HP  Pavilion             AMD        Ryzen 5         Missing     16
# 232    HP  Pavilion           Intel        Core i5            11th     16
# 272    HP  Pavilion             AMD        Ryzen 5         Missing     16
# 282    HP      Envy             AMD        Ryzen 5         Missing     16
# 294    HP  Pavilion           Intel        Core i7            11th     16
# 302    HP        HP             AMD        Ryzen 7         Missing     16
# 308    HP  Pavilion             AMD        Ryzen 5         Missing     16
# 315    HP      Envy           Intel        Core i7            10th     16
# 332    HP  Pavilion             AMD        Ryzen 7         Missing     16
# ...

# %%
#to get ramgb of 16 laptop count
lap_gb.count()
lap_gb
# Out:
#       brand       model processor_brand processor_name processor_gnrtn ram_gb  \
# 17       HP    Pavilion           Intel        Core i5            11th     16
# 22     ASUS    VivoBook           Intel        Core i7            10th     16
# 31   Lenovo     Ideapad           Intel        Core i5            11th     16
# 37      MSI        GF65           Intel        Core i7            10th     16
# 49   Lenovo     IdeaPad           Intel        Core i5            11th     16
# 64       HP    Pavilion             AMD        Ryzen 7         Missing     16
# 74    APPLE     MacBook           Apple   M1 Processor         Missing     16
# 75     acer    Predator           Intel        Core i7            11th     16
# 76     ASUS        ASUS             AMD        Ryzen 7         Missing     16
# 86      MSI      Katana           Intel        Core i5            11th     16
# 87    APPLE     MacBook           Apple   M1 Processor         Missing     16
# ...

# %%
#to calculate laptop datatypes
lap.dtypes
# Out:
# brand               object
# model               object
# processor_brand     object
# processor_name      object
# processor_gnrtn     object
# ram_gb              object
# ram_type            object
# ssd                  int64
# hdd                  int64
# os                  object
# os_bit               int64
# graphic_card_gb      int64
# weight              object
# display_size        object
# warranty             int64
# Touchscreen         object
# msoffice            object
# latest_price         int64
# old_price            int64
# discount             int64
# star_rating        float64
# ratings              int64
# reviews              int64
# dtype: object

# %%
#to decribe laptop objects on its dateset mathematical terms
lap_gb.describe(include='O')
# Out:
#        brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# count    239       239             239            239             239    239
# unique    10        53               3              9               6      1
# top     ASUS  Pavilion           Intel        Core i7            11th     16
# freq      78        19             154             79             114    239
#
#        ram_type       os  weight display_size Touchscreen msoffice
# count       239      239     239          239         239      239
# unique        7        2       3           13           2        2
# top        DDR4  Windows  Casual         15.6          No       No
# freq        183      224     185           84         189      154

# %%
lap
# Out:
#       brand       model processor_brand processor_name processor_gnrtn ram_gb  \
# 0      ASUS     Celeron           Intel   Celeron Dual         Missing      4
# 1      ASUS    VivoBook           Intel        Core i3            10th      8
# 2      ASUS    Vivobook           Intel        Core i3            10th      8
# 3        HP        Core           Intel        Core i3            11th      8
# 4        HP        Core           Intel        Core i5            11th      8
# 5    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 6        HP         15s             AMD        Ryzen 3         Missing      8
# 7      ASUS        Core           Intel        Core i3            11th      4
# 8      DELL      Vostro           Intel        Core i3            10th      8
# 9    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 10       HP        Core           Intel        Core i5            11th      8
# ...

# %%
#to find out os is assigned to Windows,if not return false
lap['os']=='Windows'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
#        ...
# 884     True
# 885     True
# 886     True
# 887    False
# 888     True
# 889     True
# 890    False
# 891     True
# 892     True
# 893     True
# 894     True
# 895    False
# Name: os, Length: 896, dtype: bool

# %%
#to find out the counts of laptop of each datasets
lap.count()
# Out:
# brand              896
# model              896
# processor_brand    896
# processor_name     895
# processor_gnrtn    896
# ram_gb             871
# ram_type           871
# ssd                896
# hdd                896
# os                 896
# os_bit             896
# graphic_card_gb    896
# weight             896
# display_size       896
# warranty           896
# Touchscreen        896
# msoffice           896
# latest_price       896
# old_price          896
# discount           896
# star_rating        896
# ratings            896
# reviews            896
# dtype: int64

# %%
#to find out the correlation(x,y) of laptop datasets
lap.corr()
# Out:
#                       ssd       hdd    os_bit  graphic_card_gb  warranty  \
# ssd              1.000000 -0.461789  0.233743         0.280814  0.204786
# hdd             -0.461789  1.000000 -0.014646        -0.080640 -0.049664
# os_bit           0.233743 -0.014646  1.000000        -0.139860  0.290472
# graphic_card_gb  0.280814 -0.080640 -0.139860         1.000000 -0.042251
# warranty         0.204786 -0.049664  0.290472        -0.042251  1.000000
# latest_price     0.541658 -0.230422 -0.058389         0.487809  0.039767
# old_price        0.485562 -0.252141 -0.007944         0.462580  0.051954
# discount         0.106299 -0.086074  0.037806         0.045117  0.071675
# star_rating     -0.120052  0.037239  0.043147        -0.013381  0.093033
# ratings         -0.178767  0.055294 -0.041343        -0.044821  0.046686
# reviews         -0.183988  0.048527 -0.051371        -0.042207  0.034957
#
#                  latest_price  old_price  discount  star_rating   ratings  \
# ...

# %%
#to remove the  datas(undatas)from laptop datasets
x=lap.dropna()
x
# Out:
#       brand       model processor_brand processor_name processor_gnrtn ram_gb  \
# 0      ASUS     Celeron           Intel   Celeron Dual         Missing      4
# 1      ASUS    VivoBook           Intel        Core i3            10th      8
# 2      ASUS    Vivobook           Intel        Core i3            10th      8
# 3        HP        Core           Intel        Core i3            11th      8
# 4        HP        Core           Intel        Core i5            11th      8
# 5    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 6        HP         15s             AMD        Ryzen 3         Missing      8
# 7      ASUS        Core           Intel        Core i3            11th      4
# 8      DELL      Vostro           Intel        Core i3            10th      8
# 9    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 10       HP        Core           Intel        Core i5            11th      8
# ...

# %%
#to find the brands types counts of laptop datasets
lap.brand.value_counts()
# Out:
# ASUS         254
# DELL         154
# Lenovo       148
# HP           142
# acer          58
# MSI           52
# APPLE         28
# Avita         18
# LG             5
# Vaio           5
# realme         4
# Nokia          4
# Infinix        4
# ALIENWARE      4
# Smartron       3
# lenovo         3
# MICROSOFT      3
# RedmiBook      3
# Mi             2
# SAMSUNG        1
# iball          1
# Name: brand, dtype: int64

# %%
#to sort the discount from laptop datasets in descending order
lap2=lap['discount'].sort_values(ascending=False)
lap2
# Out:
# 298    57
# 370    56
# 271    48
# 224    47
# 338    46
# 347    46
# 854    46
# 70     46
# 21     43
# 47     41
# 835    41
# 812    41
#        ..
# 848     0
# 780     0
# 778     0
# 776     0
# 474     0
# 772     0
# 475     0
# 765     0
# 502     0
# 503     0
# 859     0
# 683     0
# Name: discount, Length: 896, dtype: int64

# %%
#to create a pivot table of laptop datastes
table=pd.pivot_table(data=lap,index=['brand','model','processor_brand','os'],columns=['ram_gb','warranty'])
table
# Out:
#                                              discount                        \
# ram_gb                                           15.6     16
# warranty                                            0      0          1   2
# brand     model      processor_brand os
# ALIENWARE Core       NVIDIA          Missing     8.75    NaN        NaN NaN
# APPLE     2020       Apple           Mac          NaN    NaN        NaN NaN
#           2021       Apple           Mac          NaN    NaN   5.200000 NaN
#           MacBook    Apple           Mac          NaN    NaN   7.285714 NaN
#                      Intel           Mac          NaN    NaN   7.333333 NaN
# ASUS      Core       Intel           Windows      NaN  23.75        NaN NaN
#           AMD        AMD             Windows      NaN    NaN  22.000000 NaN
#           ASUS       AMD             Windows      NaN  25.50        NaN NaN
#                      Intel           Windows      NaN  16.50  23.000000 NaN
# ...

# %%
#to find out the aggregate fun on laptop price with pivot table on laptop datasets
table=pd.pivot_table(data=lap,index=['processor_brand','processor_name','processor_gnrtn'],values=['latest_price'],aggfunc=('sum','mean'))
table
# Out:
#                                                     latest_price
#                                                             mean         sum
# processor_brand processor_name    processor_gnrtn
# 512             GB SSD            Missing          149990.000000    149990.0
# 64              GB eMMC           Missing           61745.000000     61745.0
# AMD             5                 Missing           75560.000000    226680.0
#                 A6-9225 Processor Missing           24990.000000     24990.0
#                 APU Dual          Missing           21978.000000    153846.0
#                 Athlon Dual       Missing           29444.500000     58889.0
#                 Dual Core         Missing           30990.000000     61980.0
#                 Quad              Missing           19990.000000     19990.0
#                 Ryzen 3           Missing           39258.769231   1020728.0
#                 Ryzen 5           Missing           60961.317073   4998828.0
# ...

# %%
#to find out the aggregate function on laptop datasets
lap.agg(['mean','std','median','var'])
# Out:
#                   ssd            hdd      os_bit  graphic_card_gb  warranty  \
# mean       431.750000     190.857143   59.178571         1.198661  0.691964
# std        316.436824     401.181158   11.453644         2.057454  0.606282
# median     512.000000       0.000000   64.000000         0.000000  1.000000
# var     100132.263687  160946.321468  131.185954         4.233116  0.367578
#
#         latest_price     old_price    discount  star_rating       ratings  \
# mean    7.630986e+04  8.813415e+04   18.527902     2.980469  3.673917e+02
# std     4.661335e+04  5.571965e+04   10.508486     1.965254  1.106309e+03
# median  6.349400e+04  7.805250e+04   19.000000     4.100000  1.900000e+01
# var     2.172805e+09  3.104679e+09  110.428271     3.862221  1.223920e+06
#
#              reviews
# mean       46.152902
# std       136.079586
# median      3.000000
# var     18517.653690

# %%
#to rename the headings at laptop datasets(eg:brand is used here)
lap.rename(columns={'brand':'Brand'},inplace=True) 
lap
# Out:
#       Brand       model processor_brand processor_name processor_gnrtn ram_gb  \
# 0      ASUS     Celeron           Intel   Celeron Dual         Missing      4
# 1      ASUS    VivoBook           Intel        Core i3            10th      8
# 2      ASUS    Vivobook           Intel        Core i3            10th      8
# 3        HP        Core           Intel        Core i3            11th      8
# 4        HP        Core           Intel        Core i5            11th      8
# 5    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 6        HP         15s             AMD        Ryzen 3         Missing      8
# 7      ASUS        Core           Intel        Core i3            11th      4
# 8      DELL      Vostro           Intel        Core i3            10th      8
# 9    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 10       HP        Core           Intel        Core i5            11th      8
# ...

# %%
#to get the line chart of what brand does laptop have in matplotlab
import matplotlib.pyplot as plt
lap= ["ASUS","HP","DELL","Lenovo"]
plt.plot(lap)
plt.show()

# %%
#to get laptop specifocation of 2022 cleaned laptop in graph prediction
lap=["ASUS","HP","DELL","Lenovo"]
ram_gb=[8,16,32,64]
plt.plot(lap)
plt.plot(ram_gb)
plt.title("LAPTOP SPECIFICATION")
plt.xlabel("Brand")
plt.ylabel("Gigabytes")
plt.grid()
plt.show()

# %%
#to get piechart of ram_gb from laptop datasets
ram_gb= [4,8,16]
color=['b','green','r']
label=['b','green','r']
plt.pie(ram_gb, colors=color,labels=label,autopct="GB")
plt.show()

# %%
#to get the percent of ram_gb from laptop datasets by pie_chart
ram_gb= [4,8,16]
color=['b','green','r']
label=['b','green','r']
plt.pie(ram_gb, colors=color,labels=ram_gb,autopct="%0.0f%%", pctdistance=0.9,shadow=True, counterclock=False)
plt.show()

# %%
 #by doing in matplotlab in pyhton the laptop datasets
import pandas as pd
import matplotlib.pyplot as plt
lap=pd.read_csv("C:\\Users\\HP\\Downloads\\Cleaned_Laptop_data.csv")
lap
# Out:
#       brand       model processor_brand processor_name processor_gnrtn ram_gb  \
# 0      ASUS     Celeron           Intel   Celeron Dual         Missing      4
# 1      ASUS    VivoBook           Intel        Core i3            10th      8
# 2      ASUS    Vivobook           Intel        Core i3            10th      8
# 3        HP        Core           Intel        Core i3            11th      8
# 4        HP        Core           Intel        Core i5            11th      8
# 5    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 6        HP         15s             AMD        Ryzen 3         Missing      8
# 7      ASUS        Core           Intel        Core i3            11th      4
# 8      DELL      Vostro           Intel        Core i3            10th      8
# 9    Lenovo     IdeaPad           Intel        Core i3            10th      8
# 10       HP        Core           Intel        Core i5            11th      8
# ...

# %%
#to get first portion from laptop datasets
import pandas as pd
import matplotlib.pyplot as plt
lap=pd.read_csv("C:\\Users\\HP\\Downloads\\Cleaned_Laptop_data.csv")
lap.head()
# Out:
#   brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# 0  ASUS   Celeron           Intel   Celeron Dual         Missing      4
# 1  ASUS  VivoBook           Intel        Core i3            10th      8
# 2  ASUS  Vivobook           Intel        Core i3            10th      8
# 3    HP      Core           Intel        Core i3            11th      8
# 4    HP      Core           Intel        Core i5            11th      8
#
#   ram_type  ssd   hdd       os  ...  display_size  warranty Touchscreen  \
# 0     DDR4    0  1024  Windows  ...          15.6         1          No
# 1     DDR4  512     0  Windows  ...          15.6         1          No
# 2     DDR4    0  1024  Windows  ...          14.1         1          No
# 3     DDR4  512     0  Windows  ...          15.6         1          No
# 4     DDR4  512     0  Windows  ...          15.6         0          No
#
#   msoffice  latest_price old_price discount  star_rating  ratings  reviews
# ...

# %%
#to get last portion from laptop datasets
import pandas as pd
import matplotlib.pyplot as plt
lap=pd.read_csv("C:\\Users\\HP\\Downloads\\Cleaned_Laptop_data.csv")
lap.tail()
# Out:
#       brand     model processor_brand processor_name processor_gnrtn ram_gb  \
# 891    DELL      Core           Intel        Core i3            10th      8
# 892    DELL      Core           Intel        Core i3            10th      8
# 893      HP  Pavilion           Intel        Core i5             8th      8
# 894    ASUS  Vivobook           Intel        Core i3            10th      4
# 895  Lenovo       v15           Intel        Core i3            10th      4
#
#     ram_type  ssd   hdd       os  ...  display_size  warranty Touchscreen  \
# 891     DDR4  256  1024  Windows  ...          15.6         0          No
# 892     DDR4    0  1024  Windows  ...         14.96         0          No
# 893     DDR4  128     0  Windows  ...          13.3         1          No
# 894     DDR4    0  1024  Windows  ...          14.1         0          No
# 895     DDR4    0  1024  Missing  ...          15.6         0          No
#
# ...

# %%
#to get the first 50datasets from laptop datasets
lap1=lap.head(50)
lap1
# Out:
#         brand       model processor_brand  processor_name processor_gnrtn  \
# 0        ASUS     Celeron           Intel    Celeron Dual         Missing
# 1        ASUS    VivoBook           Intel         Core i3            10th
# 2        ASUS    Vivobook           Intel         Core i3            10th
# 3          HP        Core           Intel         Core i3            11th
# 4          HP        Core           Intel         Core i5            11th
# 5      Lenovo     IdeaPad           Intel         Core i3            10th
# 6          HP         15s             AMD         Ryzen 3         Missing
# 7        ASUS        Core           Intel         Core i3            11th
# 8        DELL      Vostro           Intel         Core i3            10th
# 9      Lenovo     IdeaPad           Intel         Core i3            10th
# 10         HP        Core           Intel         Core i5            11th
# 11         HP       Ryzen             AMD         Ryzen 3         Missing
# ...

# %%
#to get the valuecounts of brand laptop datsets
lap.brand.value_counts()
# Out:
# ASUS         254
# DELL         154
# Lenovo       148
# HP           142
# acer          58
# MSI           52
# APPLE         28
# Avita         18
# LG             5
# Vaio           5
# realme         4
# Nokia          4
# Infinix        4
# ALIENWARE      4
# Smartron       3
# lenovo         3
# MICROSOFT      3
# RedmiBook      3
# Mi             2
# SAMSUNG        1
# iball          1
# Name: brand, dtype: int64

# %%
#to get the last 50datasets from laptop datasets
lap1=lap.tail(50)
lap1
# Out:
#         brand       model processor_brand processor_name processor_gnrtn  \
# 846        HP  Chromebook              64        GB eMMC         Missing
# 847        HP    Pavilion             AMD        Ryzen 7         Missing
# 848        HP        Core           Intel        Core i5             7th
# 849      ASUS        Core           Intel        Core i3            11th
# 850      ASUS     ZenBook           Intel        Core i7             8th
# 851      acer        Core           Intel        Core i3            11th
# 852        HP    Pavilion           Intel        Core i5            11th
# 853      DELL        Core           Intel        Core i3            11th
# 854    Lenovo   ThinkBook           Intel        Core i5            11th
# 855      ASUS  ExpertBook           Intel        Core i3            10th
# 856     Avita       Liber           Intel        Core i5             8th
# 857     Avita       Liber           Intel        Core i5             8th
# ...

# %%
#to get what type of gb does laptop datasets have
lap1["ram_gb"].unique()
# Out:
# array(['Access', '16', '4', '8'], dtype=object)

# %%
#to get the no of value counts of each gb in laptop datasets
lap_count=lap1["ram_gb"].value_counts()
lap_count
# Out:
# 8         31
# 4         13
# 16         5
# Access     1
# Name: ram_gb, dtype: int64
